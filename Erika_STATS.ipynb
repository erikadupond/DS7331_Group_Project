# %% [markdown]
# # Data Statistics
# ### Here are the statistics covering the mean, median, mode, and variance of all the variables.

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])

mean = df_numeric.mean().round(1)
median =  df_numeric.median().round(1)   
mode = df_numeric.mode().round(1)
var = df_numeric.var().round(1)

print("Statistics Summary:")
print("Mean:\n", mean)     
print("Median:\n", median)
print("Mode:\n", mode)
print("Variance:\n", var)
